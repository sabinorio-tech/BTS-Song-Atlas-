# %%
import pandas as pd
from pathlib import Path

# %%
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
RAW_DIR = PROJECT_ROOT / "data" / "raw"

albums = pd.read_csv(RAW_DIR / "spotify_albums.csv")
tracks = pd.read_csv(RAW_DIR / "spotify_tracks.csv")

# %% [markdown]
# ## 1. Quick Inspection

# %%
albums.head()
# Out:
#                  album_id                           album_name album_type  \
# 0  6iPjmGZeonxBZ9r7Cjkezq                        KEEP SWIMMING      album
# 1  3ukkRHDHbN8tNRPKsGZR1h                              ARIRANG      album
# 2  7xLhqoM0ilHRKUg2irVSDI  PERMISSION TO DANCE ON STAGE - LIVE      album
# 3  6al2VdKbb6FIz9d7lU7WRB                                Proof      album
# 4  6nYfHQnvkvOTNHnOhDT3sr                                   BE      album
#
#   release_date  total_tracks  \
# 0   2026-03-27             9
# 1   2026-03-20            14
# 2   2025-07-18            22
# 3   2022-06-10            35
# 4   2020-11-20             8
#
#                                          spotify_url  \
# 0  https://open.spotify.com/album/6iPjmGZeonxBZ9r...
# 1  https://open.spotify.com/album/3ukkRHDHbN8tNRP...
# 2  https://open.spotify.com/album/7xLhqoM0ilHRKUg...
# 3  https://open.spotify.com/album/6al2VdKbb6FIz9d...
# 4  https://open.spotify.com/album/6nYfHQnvkvOTNHn...
#
#                                            image_url
# 0  https://i.scdn.co/image/ab67616d0000b273dd898e...
# 1  https://i.scdn.co/image/ab67616d0000b273dfa17f...
# 2  https://i.scdn.co/image/ab67616d0000b273b79d46...
# 3  https://i.scdn.co/image/ab67616d0000b27317db30...
# 4  https://i.scdn.co/image/ab67616d0000b273c07d5d...

# %%
albums.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      77 non-null     str
#  1   album_name    77 non-null     str
#  2   album_type    77 non-null     str
#  3   release_date  77 non-null     str
#  4   total_tracks  77 non-null     int64
#  5   spotify_url   77 non-null     str
#  6   image_url     77 non-null     str
# dtypes: int64(1), str(6)
# memory usage: 4.3 KB

# %%
tracks.head()
# Out:
#                  track_id                              track_name  \
# 0  6nt3AoYjkaqXMZhypTBky1                                    SWIM
# 1  7EytKcb3klVPpN5IW1sj1Y      SWIM with RM (Chill Hip Hop Remix)
# 2  5dZLsPskKzph16LWo31uxL  SWIM with Jin (Alternative Rock Remix)
# 3  5AL5OrvyIMPqKjl9iw3xO5   SWIM with SUGA (Melodic Techno Remix)
# 4  3MCJY7lXCHa0UNIjsAucaJ       SWIM with j-hope (Afrobeat Remix)
#
#                  album_id     album_name  track_number  duration_ms  explicit  \
# 0  6iPjmGZeonxBZ9r7Cjkezq  KEEP SWIMMING             1       159007     False
# 1  6iPjmGZeonxBZ9r7Cjkezq  KEEP SWIMMING             2       163226     False
# 2  6iPjmGZeonxBZ9r7Cjkezq  KEEP SWIMMING             3       193813     False
# 3  6iPjmGZeonxBZ9r7Cjkezq  KEEP SWIMMING             4       219573     False
# 4  6iPjmGZeonxBZ9r7Cjkezq  KEEP SWIMMING             5       153133     False
#
#                                          spotify_url
# 0  https://open.spotify.com/track/6nt3AoYjkaqXMZh...
# 1  https://open.spotify.com/track/7EytKcb3klVPpN5...
# 2  https://open.spotify.com/track/5dZLsPskKzph16L...
# 3  https://open.spotify.com/track/5AL5OrvyIMPqKjl...
# 4  https://open.spotify.com/track/3MCJY7lXCHa0UNI...

# %%
tracks.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 441 entries, 0 to 440
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   track_id      441 non-null    str
#  1   track_name    441 non-null    str
#  2   album_id      441 non-null    str
#  3   album_name    441 non-null    str
#  4   track_number  441 non-null    int64
#  5   duration_ms   441 non-null    int64
#  6   explicit      441 non-null    bool
#  7   spotify_url   441 non-null    str
# dtypes: bool(1), int64(2), str(5)
# memory usage: 24.7 KB

# %% [markdown]
# ## 2. Check duplicate album names

# %%
albums["album_name"].value_counts().head(20)
# Out:
# album_name
# Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni Long) (FAST X Soundtrack)    2
# KEEP SWIMMING                                                             1
# ARIRANG                                                                   1
# PERMISSION TO DANCE ON STAGE - LIVE                                       1
# Proof                                                                     1
# BE                                                                        1
# MAP OF THE SOUL : 7 ~ THE JOURNEY ~                                       1
# MAP OF THE SOUL : 7                                                       1
# MAP OF THE SOUL : PERSONA                                                 1
# Love Yourself 結 'Answer'                                                  1
# Love Yourself 轉 'Tear'                                                    1
# FACE YOURSELF                                                             1
# Love Yourself 承 'Her'                                                     1
# You Never Walk Alone                                                      1
# Wings                                                                     1
# Youth                                                                     1
# The Most Beautiful Moment in Life: Young Forever                          1
# The Most Beautiful Moment in Life Pt.2                                    1
# The Most Beautiful Moment in Life Pt.1                                    1
# Wake Up (Standard Edition)                                                1
# Name: count, dtype: int64

# %%
albums[albums["album_name"].duplicated(keep=False)].sort_values("album_name")
# Out:
#                   album_id                                         album_name  \
# 28  2H5nzViLpbX8JzY1cQMVza  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
# 29  0LyIwn8KquuxN0egv7wq8Z  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
#
#    album_type release_date  total_tracks  \
# 28     single   2023-05-18             2
# 29     single   2023-05-18             3
#
#                                           spotify_url  \
# 28  https://open.spotify.com/album/2H5nzViLpbX8JzY...
# 29  https://open.spotify.com/album/0LyIwn8KquuxN0e...
#
#                                             image_url
# 28  https://i.scdn.co/image/ab67616d0000b273be4afa...
# 29  https://i.scdn.co/image/ab67616d0000b27321ba73...

# %% [markdown]
# ## 3. Check duplicate track names

# %%
tracks[tracks["track_name"].duplicated(keep=False)].sort_values("track_name")
# Out:
#                    track_id             track_name                album_id  \
# 217  3KVOfGrYVjoP1w8T2HVltm                  2! 3!  1vhNGBTFoaSTLbHjPGFIlF
# 199  0G1Y5QG8wULxMzm45vqPIZ                  2! 3!  6THpewjqJ15ORBJkh5CEYb
# 216  52d5NT69mkmr6WzvQJ9vHr      21st Century Girl  1vhNGBTFoaSTLbHjPGFIlF
# 198  6GxNA9J3P70amAXKUPghid      21st Century Girl  6THpewjqJ15ORBJkh5CEYb
# 161  4lAE47gj539h8R1yxPhhGG          Airplane pt.2  4NIqCxqP9o8Tp6tGLBqd8O
# ..                      ...                    ...                     ...
# 246  2HMVg8AqrijDGKu0U5bVNH             Whalien 52  1k5bJ8l5oL5xxVBVHjil09
# 315  0nZaV8LwxHeg8TqFy193IL         Where You From  5r35iS0uSSoQBKzQj0IeI3
# 305  6gGCS5r2t5uxaeBWAPeBp2         Where You From  0pX41mddl0CZXxpxkQ7347
# 426  1OVUCNaV0gdltLjbpsoZwH  血、汗、涙 - Japanese ver.  1rxOBsRqYTRBhltSLWjseF
# 167  6u1ILVDFXcmQGQGCA3h849  血、汗、涙 - Japanese ver.  66J1OXSaS3hBZASOV3el8t
#
#                                            album_name  track_number  \
# 217                                             Wings            14
# 199                              You Never Walk Alone            14
# 216                                             Wings            13
# 198                              You Never Walk Alone            13
# 161                            Love Yourself 轉 'Tear'             8
# ..                                                ...           ...
# 246  The Most Beautiful Moment in Life: Young Forever             3
# 315                                  Skool Luv Affair             4
# 305               Skool Luv Affair (Special Addition)             6
# 426                                             血、汗、涙             1
# 167                                     FACE YOURSELF             3
#
#      duration_ms  explicit                                        spotify_url
# 217       272537     False  https://open.spotify.com/track/3KVOfGrYVjoP1w8...
# 199       272537     False  https://open.spotify.com/track/0G1Y5QG8wULxMzm...
# 216       192596     False  https://open.spotify.com/track/52d5NT69mkmr6Wz...
# 198       192596     False  https://open.spotify.com/track/6GxNA9J3P70amAX...
# 161       218614     False  https://open.spotify.com/track/4lAE47gj539h8R1...
# ..           ...       ...                                                ...
# 246       243552     False  https://open.spotify.com/track/2HMVg8AqrijDGKu...
# 315       240106     False  https://open.spotify.com/track/0nZaV8LwxHeg8Tq...
# 305       240106     False  https://open.spotify.com/track/6gGCS5r2t5uxaeB...
# 426       215053     False  https://open.spotify.com/track/1OVUCNaV0gdltLj...
# 167       216706     False  https://open.spotify.com/track/6u1ILVDFXcmQGQG...
#
# [219 rows x 8 columns]

# %% [markdown]
# ## 4. Basic cleaning

# %%
albums_clean = albums.copy()
tracks_clean = tracks.copy()

albums_clean["album_name"] = albums_clean["album_name"].str.strip()
tracks_clean["track_name"] = tracks_clean["track_name"].str.strip()
tracks_clean["album_name"] = tracks_clean["album_name"].str.strip()

albums_clean["release_date"] = pd.to_datetime(
    albums_clean["release_date"],
    errors="coerce"
)
albums_clean["release_year"] = albums_clean["release_date"].dt.year

# %% [markdown]
# ## 5. Remove exact duplicate rows

# %%
albums_clean = albums_clean.drop_duplicates()
tracks_clean = tracks_clean.drop_duplicates()

# %% [markdown]
# ## 6. Before and after summary

# %%
print("Albums:", albums.shape, "->", albums_clean.shape)
print("Tracks:", tracks.shape, "->", tracks_clean.shape)
print("Album rows removed:", len(albums) - len(albums_clean))
print("Track rows removed:", len(tracks) - len(tracks_clean))
print("Repeated track names are preserved across legitimate Spotify releases.")
# Out:
# Albums: (77, 7) -> (77, 8)
# Tracks: (441, 8) -> (441, 8)
# Album rows removed: 0
# Track rows removed: 0
# Repeated track names are preserved across legitimate Spotify releases.

# %% [markdown]
# ## 7. Final validation

# %%
print("Clean albums:", albums_clean.shape)
print("Clean tracks:", tracks_clean.shape)
# Out:
# Clean albums: (77, 8)
# Clean tracks: (441, 8)

# %%
albums_clean.info()

tracks_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      77 non-null     str
#  1   album_name    77 non-null     str
#  2   album_type    77 non-null     str
#  3   release_date  77 non-null     datetime64[us]
#  4   total_tracks  77 non-null     int64
#  5   spotify_url   77 non-null     str
#  6   image_url     77 non-null     str
#  7   release_year  77 non-null     int32
# dtypes: datetime64[us](1), int32(1), int64(1), str(5)
# memory usage: 4.6 KB
# <class 'pandas.DataFrame'>
# RangeIndex: 441 entries, 0 to 440
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   track_id      441 non-null    str
#  1   track_name    441 non-null    str
#  2   album_id      441 non-null    str
#  3   album_name    441 non-null    str
#  4   track_number  441 non-null    int64
#  5   duration_ms   441 non-null    int64
#  6   explicit      441 non-null    bool
#  7   spotify_url   441 non-null    str
# dtypes: bool(1), int64(2), str(5)
# memory usage: 24.7 KB

# %%
print("Album missing values:")
print(albums_clean.isna().sum())
print("\nTrack missing values:")
print(tracks_clean.isna().sum())
# Out:
# Album missing values:
# album_id        0
# album_name      0
# album_type      0
# release_date    0
# total_tracks    0
# spotify_url     0
# image_url       0
# release_year    0
# dtype: int64
#
# Track missing values:
# track_id        0
# track_name      0
# album_id        0
# album_name      0
# track_number    0
# duration_ms     0
# explicit        0
# spotify_url     0
# dtype: int64

# %%
print("Duplicate album rows:", albums_clean.duplicated().sum())
print("Duplicate track rows:", tracks_clean.duplicated().sum())
# Out:
# Duplicate album rows: 0
# Duplicate track rows: 0

# %%
print("Album IDs unique:", albums_clean["album_id"].is_unique)
# Out:
# Album IDs unique: True

# %%
print("Track IDs unique:", tracks_clean["track_id"].is_unique)
# Out:
# Track IDs unique: True

# %%
albums_clean["album_name"].value_counts().head(20)
# Out:
# album_name
# Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni Long) (FAST X Soundtrack)    2
# KEEP SWIMMING                                                             1
# ARIRANG                                                                   1
# PERMISSION TO DANCE ON STAGE - LIVE                                       1
# Proof                                                                     1
# BE                                                                        1
# MAP OF THE SOUL : 7 ~ THE JOURNEY ~                                       1
# MAP OF THE SOUL : 7                                                       1
# MAP OF THE SOUL : PERSONA                                                 1
# Love Yourself 結 'Answer'                                                  1
# Love Yourself 轉 'Tear'                                                    1
# FACE YOURSELF                                                             1
# Love Yourself 承 'Her'                                                     1
# You Never Walk Alone                                                      1
# Wings                                                                     1
# Youth                                                                     1
# The Most Beautiful Moment in Life: Young Forever                          1
# The Most Beautiful Moment in Life Pt.2                                    1
# The Most Beautiful Moment in Life Pt.1                                    1
# Wake Up (Standard Edition)                                                1
# Name: count, dtype: int64

# %%
tracks_clean["track_name"].value_counts().head(30)
# Out:
# track_name
# Dynamite                                                        4
# Blood Sweat & Tears                                             3
# DNA                                                             3
# FAKE LOVE                                                       3
# IDOL                                                            3
# Butter                                                          3
# Intro : Persona                                                 3
# Jamais Vu                                                       3
# Angel Pt. 2 (feat. Jimin of BTS, Charlie Puth and Muni Long)    3
# Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni Long)              3
# SWIM                                                            2
# No More Dream                                                   2
# N.O                                                             2
# Danger                                                          2
# Spring Day                                                      2
# Boy With Luv (Feat. Halsey)                                     2
# ON                                                              2
# Life Goes On                                                    2
# Stay                                                            2
# Moon                                                            2
# Trivia 轉 : Seesaw                                               2
# Outro : Ego                                                     2
# Her                                                             2
# Filter                                                          2
# Friends                                                         2
# Singularity                                                     2
# Euphoria                                                        2
# Dimple                                                          2
# Stay Gold                                                       2
# Boy With Luv - Japanese ver.                                    2
# Name: count, dtype: int64

# %%
tracks_clean["duration_ms"].describe()
# Out:
# count       441.000000
# mean     214618.117914
# std       48511.047636
# min       41757.000000
# 25%      192596.000000
# 50%      224920.000000
# 75%      241973.000000
# max      352133.000000
# Name: duration_ms, dtype: float64

# %%
albums_clean["release_date"].min(), albums_clean["release_date"].max()
# Out:
# (Timestamp('2013-06-12 00:00:00'), Timestamp('2026-03-27 00:00:00'))

# %%
albums_clean["album_type"].value_counts()
# Out:
# album_type
# single    53
# album     24
# Name: count, dtype: int64

# %%
tracks_clean["explicit"].value_counts()
# Out:
# explicit
# False    438
# True       3
# Name: count, dtype: int64

# %%
print("Every track belongs to a clean album:", tracks_clean["album_id"].isin(albums_clean["album_id"]).all())
# Out:
# Every track belongs to a clean album: True

# %%
album_names_match = tracks_clean[["album_id", "album_name"]].drop_duplicates().merge(
    albums_clean[["album_id", "album_name"]],
    on="album_id",
    suffixes=("_track", "_album")
)
print("Track album names match album data:", (album_names_match["album_name_track"] == album_names_match["album_name_album"]).all())
# Out:
# Track album names match album data: True

# %%
tracks_clean.groupby("album_id").size().sort_values(ascending=False).head()
# Out:
# album_id
# 6al2VdKbb6FIz9d7lU7WRB    35
# 43wFM1HquliY3iwKWzPN4y    26
# 1k5bJ8l5oL5xxVBVHjil09    23
# 7xLhqoM0ilHRKUg2irVSDI    22
# 5W1XY5ucNATjTULERvXx9j    20
# dtype: int64

# %%
expected = albums_clean.set_index("album_id")["total_tracks"]

actual = tracks_clean.groupby("album_id").size()

comparison = (
    expected.to_frame("expected")
    .join(actual.rename("actual"))
)

comparison["match"] = comparison["expected"] == comparison["actual"]

print("All expected track counts match:", comparison["match"].all())
comparison.loc[~comparison["match"]]
# Out:
# All expected track counts match: True
# Empty DataFrame
# Columns: [expected, actual, match]
# Index: []

# %% [markdown]
# ## 8. Export processed data

# %%
PROCESSED_DIR = PROJECT_ROOT / "data" / "processed"
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

albums_clean.to_csv(PROCESSED_DIR / "spotify_albums_clean.csv", index=False)
tracks_clean.to_csv(PROCESSED_DIR / "spotify_tracks_clean.csv", index=False)

# %% [markdown]
# ## 9. Verify processed exports

# %%
albums_exported = pd.read_csv(
    PROCESSED_DIR / "spotify_albums_clean.csv",
    parse_dates=["release_date"]
)
tracks_exported = pd.read_csv(PROCESSED_DIR / "spotify_tracks_clean.csv")

print("Exported albums:", albums_exported.shape)
print("Exported tracks:", tracks_exported.shape)
print("Album shape matches:", albums_exported.shape == albums_clean.shape)
print("Track shape matches:", tracks_exported.shape == tracks_clean.shape)
print("Album columns match:", albums_exported.columns.tolist() == albums_clean.columns.tolist())
print("Track columns match:", tracks_exported.columns.tolist() == tracks_clean.columns.tolist())
# Out:
# Exported albums: (77, 8)
# Exported tracks: (441, 8)
# Album shape matches: True
# Track shape matches: True
# Album columns match: True
# Track columns match: True
