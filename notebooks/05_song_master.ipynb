# %%
import pandas as pd
from pathlib import Path

# %%
BASE_DIR = Path("..")
PROCESSED_DIR = BASE_DIR / "data" / "processed"

albums = pd.read_csv(PROCESSED_DIR / "spotify_albums_clean.csv")
tracks = pd.read_csv(PROCESSED_DIR / "spotify_tracks_clean.csv")
lyrics = pd.read_csv(PROCESSED_DIR / "song_lyrics_clean.csv")

# %%
#merge tracks + albums
song_master = tracks.merge(
    albums[["album_id", "release_date", "release_year", "total_tracks", "image_url"]],
    on="album_id",
    how="left"
)

# %%
# merge lyrics
song_master = song_master.merge(
    lyrics[[
        "track_id",
        "lyrics_clean", 
        "character_count",
        "word_count", 
        "genius_title",
        "genius_artist",
        "genius_url"
    ]],
    on="track_id",
    how="left"
)

# %%
print("Song Master Shape:", song_master.shape)

print("\n" + "---" * 30)

print("Missing Values")
print(song_master.isna().sum().sort_values(ascending=False))

print("\n" + "---" * 30)

lyrics_count = song_master["lyrics_clean"].notna().sum()

print(f"Tracks with lyrics: {lyrics_count}")
print(f"Tracks without lyrics: {len(song_master) - lyrics_count}")
print(f"Coverage: {lyrics_count / len(song_master):.1%}")
# Out:
# Song Master Shape: (441, 18)
#
# ------------------------------------------------------------------------------------------
# Missing Values
# genius_title       60
# word_count         60
# lyrics_clean       60
# character_count    60
# genius_url         60
# genius_artist      60
# track_name          0
# track_id            0
# album_id            0
# album_name          0
# release_year        0
# release_date        0
# spotify_url         0
# explicit            0
# duration_ms         0
# track_number        0
# total_tracks        0
# image_url           0
# dtype: int64
#
# ------------------------------------------------------------------------------------------
# Tracks with lyrics: 381
# Tracks without lyrics: 60
# Coverage: 86.4%

# %%
# Duplicate track IDs

print("Unique track IDs:", song_master["track_id"].is_unique)
# Out:
# Unique track IDs: True

# %%
# Duplicate rows

print("Duplicate rows:", song_master.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
# Missing album metadata

print(
    "Tracks missing release year:",
    song_master["release_year"].isna().sum()
)
# Out:
# Tracks missing release year: 0

# %%
song_master.to_csv(
    PROCESSED_DIR / "song_master.csv",
    index=False
)

print("Saved:", PROCESSED_DIR / "song_master.csv")
print("Shape:", song_master.shape)
# Out:
# Saved: ../data/processed/song_master.csv
# Shape: (441, 18)

# %%
check = pd.read_csv(PROCESSED_DIR / "song_master.csv")

print(check.shape)
check.head()
# Out:
# (441, 18)
#                  track_id                              track_name  \
# 0  6nt3AoYjkaqXMZhypTBky1                                    SWIM
# 1  7EytKcb3klVPpN5IW1sj1Y      SWIM with RM (Chill Hip Hop Remix)
# 2  5dZLsPskKzph16LWo31uxL  SWIM with Jin (Alternative Rock Remix)
# 3  5AL5OrvyIMPqKjl9iw3xO5   SWIM with SUGA (Melodic Techno Remix)
# 4  3MCJY7lXCHa0UNIjsAucaJ       SWIM with j-hope (Afrobeat Remix)
#
#                  album_id     album_name  track_number  duration_ms  explicit  \
# 0  6iPjmGZeonxBZ9r7Cjkezq  KEEP SWIMMING             1       159007     False
# 1  6iPjmGZeonxBZ9r7Cjkezq  KEEP SWIMMING             2       163226     False
# 2  6iPjmGZeonxBZ9r7Cjkezq  KEEP SWIMMING             3       193813     False
# 3  6iPjmGZeonxBZ9r7Cjkezq  KEEP SWIMMING             4       219573     False
# 4  6iPjmGZeonxBZ9r7Cjkezq  KEEP SWIMMING             5       153133     False
#
#                                          spotify_url release_date  \
# 0  https://open.spotify.com/track/6nt3AoYjkaqXMZh...   2026-03-27
# 1  https://open.spotify.com/track/7EytKcb3klVPpN5...   2026-03-27
# 2  https://open.spotify.com/track/5dZLsPskKzph16L...   2026-03-27
# 3  https://open.spotify.com/track/5AL5OrvyIMPqKjl...   2026-03-27
# 4  https://open.spotify.com/track/3MCJY7lXCHa0UNI...   2026-03-27
#
#    release_year  total_tracks  \
# 0          2026             9
# 1          2026             9
# 2          2026             9
# 3          2026             9
# 4          2026             9
#
#                                            image_url  \
# 0  https://i.scdn.co/image/ab67616d0000b273dd898e...
# 1  https://i.scdn.co/image/ab67616d0000b273dd898e...
# 2  https://i.scdn.co/image/ab67616d0000b273dd898e...
# 3  https://i.scdn.co/image/ab67616d0000b273dd898e...
# 4  https://i.scdn.co/image/ab67616d0000b273dd898e...
#
#                                         lyrics_clean  character_count  \
# 0  Swim, swim\nWater falling off your skin\nSwim,...           1872.0
# 1  Swim, swim\nWater fallin' off your skin\nSwim,...           1816.0
# 2  Swim, swim\nWater falling off your skin\nSwim,...           1841.0
# 3  Swim, swim\nWater falling off your skin\nSwim,...           2312.0
# 4  Swim, swim\nWater falling off your skin\nSwim,...           1877.0
#
#    word_count                            genius_title genius_artist  \
# 0       370.0                                    SWIM           BTS
# 1       362.0      SWIM with RM (Chill Hip Hop Remix)           BTS
# 2       364.0  SWIM with Jin (Alternative Rock Remix)           BTS
# 3       455.0   SWIM with SUGA (Melodic Techno Remix)           BTS
# 4       370.0       SWIM with j-hope (Afrobeat Remix)           BTS
#
#                                           genius_url
# 0                 https://genius.com/Bts-swim-lyrics
# 1  https://genius.com/Bts-swim-with-rm-chill-hip-...
# 2  https://genius.com/Bts-swim-with-jin-alternati...
# 3  https://genius.com/Bts-swim-with-suga-melodic-...
# 4  https://genius.com/Bts-swim-with-j-hope-afrobe...
